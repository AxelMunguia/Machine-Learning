# %% [markdown]
# # Concatenar y apendizar Datasets

# %% [markdown]
# Data Set Information:
#
# These data are the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wines.
#
# I think that the initial data set had around 30 variables, but for some reason I only have the 13 dimensional version. I had a list of what the 30 or so variables were, but a.) I lost it, and b.), I would not know which 13 variables are included in the set.
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it )
#
# 1. Alcohol
# 2. Malic acid
# 3. Ash
# 4. Alcalinity of ash
# 5. Magnesium
# 6. Total phenols
# 7. Flavanoids
# 8. Nonflavanoid phenols
# 9. Proanthocyanins
# 10. Color intensity
# 11. Hue
# 12. OD280/OD315 of diluted wines
# 13. Proline
#
# In a classification context, this is a well posed problem with "well behaved" class structures. A good data set for first testing of a new classifier, but not very challenging.
#
#
# Attribute Information:
#
# All attributes are continuous
#
# No statistics available, but suggest to standardise variables for certain uses (e.g. for us with classifiers which are NOT scale invariant)
#
# NOTE: 1st attribute is class identifier (1-3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
data = pd.read_csv("../datasets/wine/winequality-red.csv",sep=";")
data1 = pd.read_csv("../datasets/wine/winequality-white.csv",delimiter=";")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
data1.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
data.shape,data1.shape
# Out:
# ((1599, 12), (4898, 12))

# %%
# Tiene las mismas variables
len([l for l in data.columns.values if l in data1.columns.values])==len(data.columns.values)
# Out:
# True

# %% [markdown]
# En python, tenemos dos tipos de ejes,
#
# - **axis=0 denota el eje horizontal**
# - **axis=1 denota el eje vertical**

# %%
wine_data= pd.concat([data,data1],axis=0)
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data.shape
# Out:
# (6497, 12)

# %%
data10 = wine_data.head(10)
data300 = wine_data[300:310]
data_ult=wine_data.tail(10)
wine_scramble = pd.concat([data_ult,data300,data10])

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
# 300             7.5             0.530         0.06            2.60      0.086
# ...

# %% [markdown]
# ### Datos distribuidos

# %%
data=pd.read_csv('../datasets/distributed-data/001.csv')
print(data.isnull().sum())
data.head()
# Out:
# Date          0
# sulfate    1344
# nitrate    1339
# ID            0
# dtype: int64
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %% [markdown]
# * Importar el primer fichero
# * Hacemos un bucle para ir recorriendo todos y cada uno de los ficheros.
#     * Importante tener una consistencia en el nombre de los ficheros.
#     * Importamos ficheros uno a uno.
#     * Cada uno de ellos debe apendizarse (añadirse al final del DataFrame).
# * Repetimos el bucle hasta que no queden ficheros.

# %%
filepath="../datasets/distributed-data/"
data=pd.read_csv(filepath+"/001.csv")

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
# Cargar ficheros y concatenarlos
final_length=len(data)
for i in range(2,333):
    if i<10:
        filename="00"+str(i)+".csv"
    if 10<=i<100:
        filename="0"+str(i) +".csv"
    elif i>=100:
        filename=str(i) +".csv"
    file=filepath+filename
    temp_data = pd.read_csv(file)
    final_length+=len(temp_data)
    data = pd.concat([data,temp_data],axis=0)

# %%
data.shape
# Out:
# (772087, 4)

# %%
data[40000:40010]
# Out:
#            Date  sulfate  nitrate  ID
# 555  2003-07-10      NaN      NaN  21
# 556  2003-07-11      NaN      NaN  21
# 557  2003-07-12      NaN      NaN  21
# 558  2003-07-13      NaN      NaN  21
# 559  2003-07-14     2.91    0.351  21
# 560  2003-07-15      NaN      NaN  21
# 561  2003-07-16      NaN      NaN  21
# 562  2003-07-17      NaN      NaN  21
# 563  2003-07-18      NaN      NaN  21
# 564  2003-07-19      NaN      NaN  21

# %%
from collections import Counter

# %%
Counter(data.index.values) # Repiciones de valores en el índice
# Out:
# Counter({0: 332,
#          1: 332,
#          2: 332,
#          3: 332,
#          4: 332,
#          5: 332,
#          6: 332,
#          7: 332,
#          8: 332,
#          9: 332,
#          10: 332,
#          11: 332,
#          12: 332,
#          13: 332,
#          14: 332,
#          15: 332,
#          16: 332,
#          17: 332,
#          18: 332,
#          19: 332,
#          20: 332,
#          21: 332,
#          22: 332,
#          23: 332,
#          24: 332,
#          25: 332,
#          26: 332,
#          27: 332,
#          28: 332,
#          29: 332,
#          30: 332,
#          31: 332,
#          32: 332,
#          33: 332,
#          34: 332,
#          35: 332,
#          36: 332,
#          37: 332,
#          38: 332,
#          39: 332,
#          40: 332,
#          41: 332,
#          42: 332,
#          43: 332,
#          44: 332,
#          45: 332,
#          46: 332,
#          47: 332,
#          48: 332,
#          49: 332,
# ...

# %% [markdown]
# ### Join de datasets

# %%
filepath="../datasets/athletes/"
data_main = pd.read_csv(filepath+"Medals.csv",encoding="ISO-8859-1")

# %%
data_main.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
a = data_main.Athlete.unique().tolist()
len(a)
# Out:
# 6956

# %%
data_main.shape # Existen atletas repetidos
# Out:
# (8618, 8)

# %%
data_country = pd.read_csv(filepath+"Athelete_Country_Map.csv",encoding="ISO-8859-1")

# %%
data_country.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
len(data_country)
# Out:
# 6970

# %%
Nombre_contar = Counter(data_country.Athlete)
Nombre_contar
# Out:
# Counter({'Michael Phelps': 1,
#          'Natalie Coughlin': 1,
#          'Aleksey Nemov': 1,
#          'Alicia Coutts': 1,
#          'Missy Franklin': 1,
#          'Ryan Lochte': 1,
#          'Allison Schmitt': 1,
#          'Ian Thorpe': 1,
#          'Dara Torres': 1,
#          'Cindy Klassen': 1,
#          'Nastia Liukin': 1,
#          'Marit Bjørgen': 1,
#          'Sun Yang': 1,
#          'Kirsty Coventry': 1,
#          'Libby Lenton-Trickett': 1,
#          'Inge de Bruijn': 1,
#          'Petria Thomas': 1,
#          'Gary Hall Jr.': 1,
#          'Michael Klim': 1,
#          "Susie O'Neill": 1,
#          'Jenny Thompson': 1,
#          'Pieter van den Hoogenband': 1,
#          'An Hyeon-Su': 1,
#          'Aliya Mustafina': 1,
#          'Shawn Johnson': 1,
#          'Dmitry Sautin': 1,
#          'Leontien Zijlaard-van Moorsel': 1,
#          'Petter Northug Jr.': 1,
#          'Ole Einar Bjørndalen': 1,
#          'Janica Kostelic': 1,
# ...

# %%
nombres=[]
ocasiones=[]
for k,l in Nombre_contar.items():
    if l>1:
        nombres.append(k) 
        ocasiones.append(l)
todo=list(zip(nombres,ocasiones))

# %%
todo
# Out:
# [('Richard Thompson', 2),
#  ('Gyuzel Manyurova', 2),
#  ('David Musulbes', 2),
#  ('Slobodan Nikic', 2),
#  ('Vanja Udovicic', 2),
#  ('Aleksandar Ciric', 2),
#  ('Aleksandar \x8aapic', 2),
#  ('Dejan Savic', 2),
#  ('Denis \x8aefik', 2),
#  ('Vlada Vujasinovic', 2),
#  (nan, 2),
#  ('Chen Jing', 2),
#  ('Matt Wells', 2),
#  ('Iván García', 2)]

# %%
REP= data_country[data_country.Athlete=='Aleksandar Ciric']
for k in todo:
    repetidos= data_country[data_country.Athlete== k[0]]
    REP=pd.concat([REP,repetidos])
REP
# Out:
#                 Athlete                Country
# 1029   Aleksandar Ciric                 Serbia
# 1086   Aleksandar Ciric  Serbia and Montenegro
# 528    Richard Thompson    Trinidad and Tobago
# 5692   Richard Thompson              Australia
# 608    Gyuzel Manyurova             Kazakhstan
# 721    Gyuzel Manyurova                 Russia
# 678      David Musulbes               Slovakia
# 773      David Musulbes                 Russia
# 986      Slobodan Nikic                 Serbia
# 1120     Slobodan Nikic  Serbia and Montenegro
# 1014     Vanja Udovicic                 Serbia
# 1134     Vanja Udovicic  Serbia and Montenegro
# 1029   Aleksandar Ciric                 Serbia
# 1086   Aleksandar Ciric  Serbia and Montenegro
# 1061   Aleksandar apic                 Serbia
# 1125   Aleksandar apic  Serbia and Montenegro
# 1062        Dejan Savic                 Serbia
# 1126        Dejan Savic  Serbia and Montenegro
# 1063        Denis efik                 Serbia
# ...

# %%
data_sports=pd.read_csv('../datasets/athletes/Athelete_Sports_Map.csv',encoding='ISO-8859-1')

# %%
data_sports.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
len(data_sports)
# Out:
# 6975

# %%
data_count=Counter(data_sports.Athlete)
keys=[]
values=[]
for key,value in data_count.items():
    if value>1:
        keys.append(key)
        values.append(value)
Rep= list(zip(keys,values))
Rep
# Out:
# [('Yang Wei', 2),
#  ('Wang Hao', 2),
#  ('Li Na', 2),
#  ('Richard Thompson', 2),
#  ('Kim Nam-Sun', 2),
#  ('Laura López', 2),
#  ('Ryan Bailey', 2),
#  (nan, 2),
#  ('Fabiana', 2),
#  ('Chen Jing', 2),
#  ('Nataliya Ivanova', 2),
#  ('Li Ting', 2),
#  ('Matt Ryan', 2),
#  ('Matt Wells', 2),
#  ('Rebecca Romero', 2),
#  ('Jang Seong-Ho', 2),
#  ('Zhang Nan', 2),
#  ('Juliana', 2),
#  ('Iván García', 2)]

# %%
data_rep = data_sports[data_sports.Athlete==Rep[0][0]]
for k in range(1,len(Rep)):
    data_new=data_sports[data_sports.Athlete==Rep[k][0]]
    data_rep=pd.concat([data_rep,data_new])
data_rep.head()
# Out:
#        Athlete         Sport
# 94    Yang Wei    Gymnastics
# 6341  Yang Wei     Badminton
# 136   Wang Hao  Table Tennis
# 5034  Wang Hao        Diving
# 396      Li Na        Diving

# %%
data_sports[(data_sports.Athlete==Rep[0][0])|(data_sports.Athlete==Rep[1][0])
           |(data_sports.Athlete==Rep[2][0])]
# Out:
#        Athlete         Sport
# 94    Yang Wei    Gymnastics
# 136   Wang Hao  Table Tennis
# 396      Li Na        Diving
# 4775     Li Na       Fencing
# 5034  Wang Hao        Diving
# 6341  Yang Wei     Badminton

# %%
data_rep= data_rep.drop_duplicates(subset="Athlete")
data_rep
# Out:
#                Athlete         Sport
# 94            Yang Wei    Gymnastics
# 136           Wang Hao  Table Tennis
# 396              Li Na        Diving
# 528   Richard Thompson     Athletics
# 570        Kim Nam-Sun       Archery
# 975        Laura López     Waterpolo
# 1020       Ryan Bailey     Waterpolo
# 1196           Fabiana    Volleyball
# 1308         Chen Jing    Volleyball
# 1552  Nataliya Ivanova     Taekwondo
# 1594           Li Ting        Tennis
# 2727         Matt Ryan        Rowing
# 2750        Matt Wells        Rowing
# 2825    Rebecca Romero        Rowing
# 3201     Jang Seong-Ho          Judo
# 4280         Zhang Nan    Gymnastics
# 4547           Juliana      Football
# 5021       Iván García        Diving

# %% [markdown]
# ### Merge

# %%
data_country_dp= data_country.drop_duplicates(subset="Athlete")

# %%
data_main_country = pd.merge(left=data_main,right=data_country_dp,
                            left_on="Athlete",right_on="Athlete")

# %%
data_main_country.head(10)
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
# 5  Natalie Coughlin  29.0  2012            08/12/2012            0
# 6     Aleksey Nemov  24.0  2000            10/01/2000            2
# 7     Alicia Coutts  24.0  2012            08/12/2012            1
# 8    Missy Franklin  17.0  2012            08/12/2012            4
# 9       Ryan Lochte  27.0  2012            08/12/2012            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# ...

# %%
data_country_dp.Athlete.values, data_main.Athlete.values
# Out:
# (array(['Michael Phelps', 'Natalie Coughlin', 'Aleksey Nemov', ...,
#         'Wietse van Alten', 'Sandra Wagner-Sachse', 'Rod White'],
#        dtype=object),
#  array(['Michael Phelps', 'Michael Phelps', 'Michael Phelps', ...,
#         'Wietse van Alten', 'Sandra Wagner-Sachse', 'Rod White'],
#        dtype=object))

# %%
data_main.shape, data_main_country.shape
# Out:
# ((8618, 8), (8618, 9))

# %%
data_main.columns, data_main_country.columns # Se agregó country
# Out:
# (Index(['Athlete', 'Age', 'Year', 'Closing Ceremony Date', 'Gold Medals',
#         'Silver Medals', 'Bronze Medals', 'Total Medals'],
#        dtype='object'),
#  Index(['Athlete', 'Age', 'Year', 'Closing Ceremony Date', 'Gold Medals',
#         'Silver Medals', 'Bronze Medals', 'Total Medals', 'Country'],
#        dtype='object'))

# %%
data_main[data_main.Athlete=="Michael Phelps"]
# Out:
#           Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Michael Phelps  23.0  2008            08/24/2008            8
# 1  Michael Phelps  19.0  2004            08/29/2004            6
# 2  Michael Phelps  27.0  2012            08/12/2012            4
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6

# %%
data_main_country[data_main_country.Athlete=="Michael Phelps"]
# Out:
#           Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Michael Phelps  23.0  2008            08/24/2008            8
# 1  Michael Phelps  19.0  2004            08/29/2004            6
# 2  Michael Phelps  27.0  2012            08/12/2012            4
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States

# %%
data_sports_dp =data_sports.drop_duplicates(subset="Athlete")

# %%
data_sports_dp.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_final=pd.merge(left=data_main_country,right=data_sports_dp,
                   left_on="Athlete",right_on="Athlete")

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %%
data_final1=pd.merge(right=data_main_country,left=data_sports_dp,
                   left_on="Athlete",right_on="Athlete")
data_final1.head()
# Out:
#             Athlete     Sport   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  Swimming  23.0  2008            08/24/2008            8
# 1    Michael Phelps  Swimming  19.0  2004            08/29/2004            6
# 2    Michael Phelps  Swimming  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  Swimming  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  Swimming  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %% [markdown]
# ### <font color="red"> Tipos de Joins </font>

# %%
from IPython.display import Image

# %% [markdown]
# **Inner Join <= A (Left Join), B (Right Join) <= Outer Join**

# %%
out_athletes = np.random.choice(data_main.Athlete,size=6, replace=False)

# %%
data_country_dlt = data_country_dp[(~data_country_dp.Athlete.isin(out_athletes)) & (data_country_dp.Athlete!='Michael Phelps')]
data_main_dlt = data_main[(~data_main.Athlete.isin(out_athletes)) & (data_main.Athlete!='Michael Phelps')]
data_sports_dtl = data_sports_dp[(~data_sports_dp.Athlete.isin(out_athletes)) & (data_sports_dp.Athlete!='Michael Phelps')]

# %%
data_main[data_main.Athlete.isin(out_athletes)]
# Out:
#               Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 2297  Thomas Rupprath  27.0  2004            08/29/2004            0
# 2319    B. J. Bedford  27.0  2000            10/01/2000            1
# 2367  Thomas Rupprath  23.0  2000            10/01/2000            0
# 4116    Sidney Crosby  22.0  2010            02/28/2010            1
# 4282     Kristin King  26.0  2006            02/26/2006            0
# 7516        Swin Cash  32.0  2012            08/12/2012            1
# 7596    Manu Ginóbili  31.0  2008            08/24/2008            0
# 7660        Swin Cash  24.0  2004            08/29/2004            1
# 7670    Manu Ginóbili  27.0  2004            08/29/2004            1
#
#       Silver Medals  Bronze Medals  Total Medals
# 2297              1              0             1
# 2319              0              0             1
# 2367              0              1             1
# 4116              0              0             1
# ...

# %%
data_country_dlt.shape,data_sports_dtl.shape,data_main_dlt.shape
# Out:
# ((6949, 2), (6949, 2), (8606, 8))

# %% [markdown]
# ## Inner Join
# * Devuelve un data frame con las filas que tienen valor tanto en el primero como en el segundo data frame que estamos uniendo
# * El número de filas será igual al número de filas **comunes** que tengas ambos data sets
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Inner Join B tendrá 30 filas
# * En términos de teoría de conjuntos, se trata de la intersección de los dos conjuntos

# %%
Image(filename="resources/inner-join.png")

# %%
# Data_country contiene toda la infromación
# Data_country_dlt le hace faltan los que se eliminaron
merged_innner = pd.merge(left=data_country_dp, right=data_country_dlt,how="inner", left_on="Athlete",right_on="Athlete")

# %%
data_country.shape,data_country_dlt.shape, merged_innner.shape
# Out:
# ((6970, 2), (6949, 2), (6949, 3))

# %% [markdown]
# ## Left Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho, tendrán NAs en las columnas del data frame derecho.
# * El número de filas será igual al número de filas del data frame izquierdo
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Left Join B tendrá 60 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la izquierda quien, además tiene la intersección en su interior.

# %%
Image(filename="resources/left-join.png")

# %%
merge_left=pd.merge(left=data_country_dp,right=data_country_dlt, left_on="Athlete",right_on="Athlete",how="left")

# %%
merge_left.shape,data_country_dp.shape,data_country_dlt.shape
# Out:
# ((6956, 3), (6956, 2), (6949, 2))

# %% [markdown]
# ## Right Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la derecha, sin importar si tienen correspondencia en el de la izquierda o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame izquierdo, tendrán NAs en las columnas del data frame izquierdo.
# * El número de filas será igual al número de filas del data frame derecho
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Right Join B tendrá 50 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la derecha quien, además tiene la intersección en su interior.

# %%
Image(filename="resources/right-join.png")

# %%
merge_right=pd.merge(left=data_country_dp,right=data_country_dlt, left_on="Athlete",right_on="Athlete",how="right")

# %%
merge_right.shape,data_country_dp.shape,data_country_dlt.shape
# Out:
# ((6949, 3), (6956, 2), (6949, 2))

# %% [markdown]
# ## Outer Join
# * Devuelve un data frame con todas las filas de ambos, reemplazando las ausencias de uno o de otro con NAs en la región específica..
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho (o izquierdo), tendrán NAs en las columnas del data frame derecho (o izquierdo).
# * El número de filas será igual al máximo número de filas de ambos data frames
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Outer Join B tendrá 60 + 50 - 30 = 80 filas
# * En términos de teoría de conjuntos, se trata de la unión de conjuntos.

# %%
Image(filename="resources/outer-join.png")

# %%
data_country_AF= data_country_dlt.append({"Athlete":"Axel",
                                         "Country":"México"}, ignore_index=True)

# %%
data_country_AF.tail()
# Out:
#                    Athlete        Country
# 6945      Kateryna Serdiuk        Ukraine
# 6946      Wietse van Alten    Netherlands
# 6947  Sandra Wagner-Sachse        Germany
# 6948             Rod White  United States
# 6949                  Axel         México

# %%
merge_outer = pd.merge(left=data_country_dp, right=data_country_AF,left_on="Athlete",right_on="Athlete",how="outer")

# %%
data_country_dp.shape,data_country_AF.shape,merge_outer.shape
# Out:
# ((6956, 2), (6950, 2), (6957, 3))

# %%
merge_outer.tail()
# Out:
#                    Athlete      Country_x      Country_y
# 6952      Kateryna Serdiuk        Ukraine        Ukraine
# 6953      Wietse van Alten    Netherlands    Netherlands
# 6954  Sandra Wagner-Sachse        Germany        Germany
# 6955             Rod White  United States  United States
# 6956                  Axel            NaN         México
